# %%
import openpyxl as opxl
import pandas as pd
import re
import unicodedata

# %%
#wb1 = opxl.load_workbook('Annex 18 - Reconciliation sheets Oil & Gas 15-16.xlsx')
# wb1 = opxl.load_workbook('Annex 18 - Reconciliation sheets Gems & Jade 15-16.xlsx')
#print wb1.get_sheet_names()

# %%
#xl = pd.ExcelFile('data/2015-16/Annex 18 - Reconciliation sheets Gems & Jade 15-16.xlsx')
xl = pd.ExcelFile('data/2014-15/Annex 18 - Reconciliation sheets Gems & Jade 14-15.xlsx')

sheets_list = xl.sheet_names
#df = xls.parse('Sheet1', skiprows=4, index_col=None, na_values=['NA'])
sheets_list
# Out:
# [u'C (1)',
#  u'C (2)',
#  u'C (3)',
#  u'C (4)',
#  u'C (5)',
#  u'C (6)',
#  u'C (7)',
#  u'C (8)',
#  u'C (9)',
#  u'C (10)',
#  u'C (11)',
#  u'C (12)',
#  u'C (13)',
#  u'C (14)',
#  u'C (15)',
#  u'C (16)',
#  u'C (17)',
#  u'C (18)',
#  u'C (19)',
#  u'C (20)',
#  u'C (21)',
#  u'C (22)',
#  u'C (23)',
#  u'C (24)',
#  u'C (25)',
#  u'C (26)',
#  u'C (27)',
#  u'C (28)',
#  u'C (29)',
#  u'C (30)',
#  u'C (31)',
#  u'C (32)',
#  u'C (33)',
#  u'C (34)',
#  u'C (35)',
#  u'C (36)',
#  u'C (37)',
#  u'C (38)',
#  u'C (39)',
#  u'C (40)',
#  u'C (41)',
#  u'C (42)',
#  u'C (43)',
#  u'C (44)',
#  u'C (45)',
#  u'C (46)',
#  u'C (47)',
#  u'C (48)',
#  u'C (49)',
#  u'C (50)',
#  u'C (51)',
#  u'C (52)',
#  u'C (53)',
#  u'C (54)',
#  u'C (55)',
#  u'C (56)',
#  u'C (57)',
#  u'C (58)',
#  u'C (59)',
#  u'C (60)',
#  u'C (61)',
#  u'C (62)',
#  u'C (63)',
#  u'C (64)',
#  u'C (65)',
#  u'C (66)',
#  u'C (67)',
#  u'C (68)',
#  u'C (69)',
#  u'C (70)',
#  u'C (71)',
#  u'C (72)']

# %%
def join_column_titles(text):
    #print(text)
    to_return = ""
    for t in text:
        #print(t)
        if not isinstance(t, float):
            to_return = '.'.join([to_return,(''.join(i for i in t if ord(i)<128))])
    #print("FINAL: " + to_return)
    
    # remove first '.' from the title
    return to_return[1:]

# %%
df_all = pd.DataFrame({'company_name' : [],'name_of_revenue_stream' : [],'value_reported' : []})


for s in sheets_list:
    #try:
        #df = xl.parse('C (1)', skiprows=4, index_col=None, na_values=['NA'])
        name_df = xl.parse(s, parse_cols = 'B:D')
        #print(name_df)
        company_name = name_df.columns[2]
        company_number = name_df[name_df['Company name:'] == 'Registry number'][company_name][0]
        print(company_name, company_number)

        df = xl.parse(s, skiprows=4, parse_cols = 'B:L', header=None)        
        #print(df)

        df.iloc[0:2] = df.iloc[0:2].fillna(method='ffill', axis=1)
        df.columns = df.iloc[0:2].apply(join_column_titles, axis=0)
        df = df.iloc[2:33]

        name = map(lambda x: ''.join(e for e in x if e.isalnum()) , company_name.split(' '))
        name = ' '.join(w for w in name)
        name = re.sub( '\s+', ' ', name.strip())
        filename = re.sub( '\s+', '_', name.strip())+'.csv'
    #         df.to_csv(filename)

        print(filename)
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Sale Split', \
                          'paid_to' : "Myanmar Gems Enterprise", \
                          'value_reported' : [df.loc[9,'Per Government.Final'][0]]})])
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Sales Royalties', \
                          'paid_to' : "Myanmar Gems Enterprise", \
                          'value_reported' : [df.loc[10,'Per Government.Final'][0]]})])
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Emporium Fees', \
                          'paid_to' : "Central Comittee", \
                          'value_reported' : [df.loc[25,'Per Government.Final'][0]]})])
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Other significant payments', \
                          'paid_to' : "Myanmar Gems Enterprise", \
                          'value_reported' : [df.loc[23,'Per Government.Final'][0]]})])
        
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Production Royalties', \
                          'paid_to' : "Myanmar Gems Enterprise", \
                          'value_reported' : [df.loc[7,'Per Government.Final'][0]]})])
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Production Royalties', \
                          'paid_to' : "Department of Mines", \
                          'value_reported' : [df.loc[8,'Per Government.Final'][0]]})])
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Permit Fees', \
                          'paid_to' : "Myanmar Gems Enterprise", \
                          'value_reported' : [df.loc[12,'Per Government.Final'][0]]})])
        
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Incentive Fees', \
                          'paid_to' : "Myanmar Gems Enterprise", \
                          'value_reported' : [df.loc[13,'Per Government.Final'][0]]})])
        
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Commercial Tax', \
                          'paid_to' : "Myanmar Gems Enterprise", \
                          'value_reported' : [df.loc[14,'Per Government.Final'][0]]})])
        
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Corporate Income Tax', \
                          'paid_to' : "Internal Revenue Department", \
                          'value_reported' : [df.loc[19,'Per Government.Final'][0]]})])
        
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Commercial Tax', \
                          'paid_to' : "Internal Revenue Department", \
                          'value_reported' : [df.loc[20,'Per Government.Final'][0]]})])
        
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Customs Duties', \
                          'paid_to' : "Customs Department", \
                          'value_reported' : [df.loc[21,'Per Government.Final'][0]]})])
        
        
        df_all = pd.concat([df_all, \
            pd.DataFrame({'company_name' : [name], \
                          'name_of_revenue_stream' : 'Sales Royalties', \
                          'paid_to' : "Internal Revenue Department", \
                          'value_reported' : [df.loc[22,'Per Government.Final'][0]]})])
    #         print(df.columns)
    #except:
    #    print("error parsing names from sheet \"" + s + "\"")
# Out:
# (u'Myanmar Win Gate Gems & Jewellery Mining', nan)
# Myanmar_Win_Gate_Gems_Jewellery_Mining.csv
# (u'Sein Lom Taung Tan Gems Ltd. (*)', nan)
# Sein_Lom_Taung_Tan_Gems_Ltd.csv
# (u'Yar Za Htar Ne Gems Co;Ltd. (*)', nan)
# Yar_Za_Htar_Ne_Gems_CoLtd.csv
# (u'Myanmar Imperial Jade(Gems & Jewellery) (*)', nan)
# Myanmar_Imperial_JadeGems_Jewellery.csv
# (u'Wai Aung Gabar Gems Co; Ltd. (*)', nan)
# Wai_Aung_Gabar_Gems_Co_Ltd.csv
# (u'Ayar Jade Co; Ltd.', nan)
# Ayar_Jade_Co_Ltd.csv
# (u'Myat Yamon Gems Co;Ltd. (*)', nan)
# Myat_Yamon_Gems_CoLtd.csv
# (u'Kyauk Seinn Nagar (Gems)  (*)', nan)
# Kyauk_Seinn_Nagar_Gems.csv
# (u'Myanmar Sithu Jewellery (*)', nan)
# Myanmar_Sithu_Jewellery.csv
# (u'Linn Lett Win Yadanar Gems (*)', nan)
# Linn_Lett_Win_Yadanar_Gems.csv
# (u'Yadanar Taung Tann Gems (*)', nan)
# Yadanar_Taung_Tann_Gems.csv
# (u'Khin Zaw Aung & Brothers Gems & Jewellery (*)', nan)
# Khin_Zaw_Aung_Brothers_Gems_Jewellery.csv
# (u'Shwe Gaung Gaung Gems', nan)
# ...

# %%
#df_all.to_csv('data/2015-16_gems_jade.csv')
df_all.to_csv('data/2014-15_gems_jade.csv')

df_all
# Out:
#                               company_name      name_of_revenue_stream  \
# 0   Myanmar Win Gate Gems Jewellery Mining                  Sale Split
# 0   Myanmar Win Gate Gems Jewellery Mining             Sales Royalties
# 0   Myanmar Win Gate Gems Jewellery Mining               Emporium Fees
# 0   Myanmar Win Gate Gems Jewellery Mining  Other significant payments
# 0   Myanmar Win Gate Gems Jewellery Mining        Production Royalties
# 0   Myanmar Win Gate Gems Jewellery Mining        Production Royalties
# 0   Myanmar Win Gate Gems Jewellery Mining                 Permit Fees
# 0   Myanmar Win Gate Gems Jewellery Mining              Incentive Fees
# 0   Myanmar Win Gate Gems Jewellery Mining              Commercial Tax
# 0   Myanmar Win Gate Gems Jewellery Mining        Corporate Income Tax
# 0   Myanmar Win Gate Gems Jewellery Mining              Commercial Tax
# 0   Myanmar Win Gate Gems Jewellery Mining              Customs Duties
# ...
